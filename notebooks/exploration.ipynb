# %% [markdown]
# # SafeFusion Data Exploration\n\nExploratory data analysis for accident detection dataset.

# %%
import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\n\n# Load and explore data\nprint('SafeFusion Exploration Notebook')
