# %% [markdown]
# # SafeFusion Visualization\n\nVisualize accident detection results and model predictions.

# %%
import cv2\nimport matplotlib.pyplot as plt\nfrom src.utils import draw_boxes, create_heatmap\n\n# Visualization utilities\nprint('SafeFusion Visualization Notebook')
